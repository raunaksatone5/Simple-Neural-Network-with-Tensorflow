# %% [markdown]
# <a href="https://colab.research.google.com/github/raunaksatone5/Simple-Neural-Network-with-Tensorflow/blob/main/hands_on_tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('/content/Churndata.txt')

# %%
df.head()
# Out:
#   Customer ID  Gender  Senior Citizen Partner Dependents  tenure  \
# 0  7590-VHVEA  Female               0     Yes         No       1
# 1  7590-VHVEG  Female               0     Yes         No       1
# 2  5575-GNVDE    Male               0      No         No      34
# 3  3668-QPYBK    Male               0      No         No       2
# 4  7795-CFOCW    Male               0      No         No      45
#
#   Phone Service    Multiple Lines Internet Service Online Security  ...  \
# 0            No  No phone service              DSL              No  ...
# 1            No  No phone service              DSL              No  ...
# 2           Yes                No              DSL             Yes  ...
# 3           Yes                No              DSL             Yes  ...
# 4            No  No phone service              DSL             Yes  ...
#
#   Device Protection Tech Support Streaming TV Streaming Movies  \
# 0                No           No           No               No
# ...

# %%
X = pd.get_dummies(df.drop(['Churn', 'Customer ID'], axis=1))
y = df['Churn'].apply(lambda x: 1 if x=='Yes' else 0)

# %% [markdown]
# ### Splitting the data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)

# %%
y_train.head()
# Out:
# 645     0
# 4083    1
# 6437    0
# 992     0
# 2324    1
# Name: Churn, dtype: int64

# %% [markdown]
# ### Import Libraries

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Neural Network model

# %%
model = Sequential()
model.add(Dense(units=32, activation='relu', input_dim=len(X_train.columns)))
model.add(Dense(units=64, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='sgd', metrics='accuracy')

# %% [markdown]
# ### Fitting the model

# %%
model.fit(X_train, y_train, epochs=200, batch_size=32)
# Out:
# Epoch 1/200
# 177/177 [==============================] - 1s 3ms/step - loss: 0.5021 - accuracy: 0.7526
# Epoch 2/200
# 177/177 [==============================] - 1s 4ms/step - loss: 0.4843 - accuracy: 0.7753
# Epoch 3/200
# 177/177 [==============================] - 1s 4ms/step - loss: 0.4775 - accuracy: 0.7803
# Epoch 4/200
# 177/177 [==============================] - 1s 4ms/step - loss: 0.4754 - accuracy: 0.7810
# Epoch 5/200
# 177/177 [==============================] - 1s 4ms/step - loss: 0.4714 - accuracy: 0.7839
# Epoch 6/200
# 177/177 [==============================] - 1s 5ms/step - loss: 0.4677 - accuracy: 0.7876
# Epoch 7/200
# 177/177 [==============================] - 1s 4ms/step - loss: 0.4642 - accuracy: 0.7815
# Epoch 8/200
# 177/177 [==============================] - 1s 4ms/step - loss: 0.4620 - accuracy: 0.7872
# Epoch 9/200
# 177/177 [==============================] - 1s 4ms/step - loss: 0.4616 - accuracy: 0.7867
# Epoch 10/200
# ...

# %%
y_hat = model.predict(X_test)
y_hat = [0 if val < 0.5 else 1 for val in y_hat]
# Out:
# 45/45 [==============================] - 0s 2ms/step

# %%
accuracy_score(y_test, y_hat)
# Out:
# 0.7955997161107168

# %% [markdown]
# ### 4. Saving and Reloading the model

# %%
model.save('tensorflow_model')

# %%
del model

# %%
model = load_model('tensorflow_model')
